# %%
import pandas as pd
import numpy as np

# %%
pd = pd.DataFrame(np.array([[1, 2], [3, 4]]), columns=['A', 'B'])
print(pd)

# %%
pd_2 = pd.DataFrame(np.array([[5, 6], [7, 8]]), columns=['A', 'B'])
print(pd_2)

# %%
pd_3 = pd + pd_2
print(pd_3)

# %% [markdown]
# ## Limpieza

# %%
pd_3 = pd + pd_2 + ['0']
